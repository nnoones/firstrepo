# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nuno de Abreu Nunes**
# Data Scientist (in the making)

# %% [markdown]
# *I'm interested in Data Science because in my current job I miss the intellectual challenge of analysing data, extracting patterns and meaning from it. I used to do similar stuff previously as a researcher. I'm currently working on identifying the skills I already have those I'm still missing, and developing the latter to become the best candidate for the job. And enjoying the brain workout while I do that!*

# %% [markdown]
# ### The code below defines two variables *a* and *b*, and then displays their sum:

# %%
a=5
b=7
print("The sum of ", a, " and ", b, " equals ", a+b, ".", sep="")
# Out:
# The sum of 5 and 7 equals 12.

# %% [markdown]
# #### Now for the markdown text formatting tasks
#
# Let's start with the horizontal rule:
#
# ---
#
#
# Now a bulleted list:
#
# + first item
# + second item
# + one more, that's enough
#
#
# And here's a numbered list:
#
# 1. item numero uno
# 2. this is the second item
# 3. the third item comes between the second and the fourth
# 4. well, I guess I need this item now...
#
#
# A small table with two data rows:
#
# | header1 | header2 |
# | ---- | ---- |
# | d11 | d12 |
# | d21 | d22 |
#
#
#
# Here's the link to the GitHub repository where this notebook is published:
# https://github.com/nnoones/firstrepo
#
#
# A small screenshot of this notebook being written:
# ![Screenshot of Jupyter Notebook](attachment:Screenshot%20from%202022-07-17%2023-30-52.png)
#
#
# Here's a small fenced block of `python code`:
#
# ```python
# a=5
# b=7
# print("The sum of ", a, " and ", b, " equals ", a+b, ".", sep="")
# ```
#
#
# Now a blocked quote:
# > This is a fine example of a blocked quote.
# > Let's make it two lines long.
# > Or even three.
#
#
# And last but not least, let's strike through ~~the last part of this sentence.~~
#
#
# That was ***fun!***
